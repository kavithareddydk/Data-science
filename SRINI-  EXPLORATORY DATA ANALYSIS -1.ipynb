# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#from google.collab import files
# uploaded = files.upload

# %%
data = pd.read_csv("data_clean.csv")

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.head() ## if we wont give num inside head, by default it will give top 5 rows
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
## null values: are missing values in columns, non null values are having values or data

# %%
## DATA structure;
data.shape , data.size
# Out:
# ((158, 10), 1580)

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.shape[0]
# Out:
# 158

# %%
data.shape[1]
# Out:
# 10

# %%
data.shape[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data.shape[2]
#
# IndexError: tuple index out of range

# %%
# data types
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.describe  ### we wont get in an alignment here
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]>

# %%
data.describe() ## gives only numeric data, which is meaningful to judge
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
data.describe(include = 'all')  ## gives all non numeric data
# Out:
#         Unnamed: 0       Ozone     Solar.R        Wind Temp C Month  \
# count   158.000000  120.000000  151.000000  158.000000    158   158
# unique         NaN         NaN         NaN         NaN     41     6
# top            NaN         NaN         NaN         NaN     81     9
# freq           NaN         NaN         NaN         NaN     11    34
# mean     79.500000   41.583333  185.403974    9.957595    NaN   NaN
# std      45.754781   32.620709   88.723103    3.511261    NaN   NaN
# min       1.000000    1.000000    7.000000    1.700000    NaN   NaN
# 25%      40.250000   18.000000  119.000000    7.400000    NaN   NaN
# 50%      79.500000   30.500000  197.000000    9.700000    NaN   NaN
# 75%     118.750000   61.500000  257.000000   11.875000    NaN   NaN
# max     158.000000  168.000000  334.000000   20.700000    NaN   NaN
#
#                Day    Year        Temp Weather
# count   158.000000   158.0  158.000000     155
# unique         NaN     NaN         NaN       3
# ...

# %%
data.info() ## here we have object ,int and float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# to convert object data type to numeric data type

# %%
data['Month'] =pd.to_numeric(data['Month'],errors = 'coerce') ### [1,1,S] januaray NA
data['Temp C'] =pd.to_numeric(data['Temp C'],errors = 'coerce') ## coerce will introduce NAN values as 
data['Weather'] = data['Weather'].astype('category')   ### category for categorical variables ## data['Wind'] = data['Wind'].astype('int64')

# %%
data.info()   ### from below output we can come to know that all the variables are int and float and categorical, there is no object type data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       157 non-null    float64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(5), int64(4)
# memory usage: 11.5 KB

# %%
### in pandas libraray we have an option to convert into numeric , and in numeric it can be ineteger or float. \
## but in python we have string, float, int, boolean only

# %% [markdown]
# # Drop columns

# %%
data1 = data.drop('Unnamed: 0', axis=1)  ### axis = 1 means it(unnamed=0) is one column which u need to drop
data1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# # Remove duplicated rows

# %%
## print the duplicated rows
data.duplicated()  ### but we wont want this type of data without all the row values. we need row values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool

# %%
data1[data1.duplicated()]  ## indiactes that 156th indexed row is duplicated
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data_cleaned1 = data1.drop_duplicates() ### to drop duplicates value

# %%
data_cleaned1[data_cleaned1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
TO DROP MORE COLUMNS AT A TIME
# Out:
#   Cell In[41], line 1
#     TO DROP MORE COLUMNS AT A TIME
#        ^
# SyntaxError: invalid syntax

# %%
data_cleaned2 = data_cleaned1.drop('Temp C',axis =1)
data_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# # RENAME THE COLUMNS

# %%
data_cleaned3 = data1.rename({'Solar.R':'Solar'}, axis=1)
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...    ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data_cleaned3 = data1.rename({'Year':'No of Years'},{'Temp':'Temperature'} , axis=1)  ### how to rename 2-3 coumns at a time ???
data_renamedt

# %% [markdown]
# # MISSING VALUES AND IMPUTATION

# %%
import seaborn as sns
cols =data_cleaned3.columns
colours = ['black', 'yellow'] ## specify the colours - yellow is missing, black is not missing
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours), cbar = False)
# Out:
# <Axes: >

# %%
data_of_nulls = data_cleaned3[cols].isnull()
column_names = list(data_cleaned3.columns)

data_of_nulls
# Out:
#      Ozone  Solar   Wind  Temp C  Month    Day   Year   Temp  Weather
# 0    False  False  False   False  False  False  False  False    False
# 1    False  False  False   False  False  False  False  False    False
# 2    False  False  False   False  False  False  False  False    False
# 3    False  False  False   False  False  False  False  False    False
# 4     True   True  False   False  False  False  False  False    False
# ..     ...    ...    ...     ...    ...    ...    ...    ...      ...
# 153  False  False  False   False  False  False  False  False    False
# 154  False  False  False   False  False  False  False  False    False
# 155   True  False  False   False  False  False  False  False    False
# 156  False  False  False   False  False  False  False  False    False
# 157  False  False  False   False  False  False  False  False    False
#
# [158 rows x 9 columns]

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)]  ## it will give younull values in particular columns and its row
# Out:
#      Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp Weather
# 4      NaN    NaN  14.3    56.0    5.0    5  2010    56       S
# 5     28.0    NaN  14.9    66.0    5.0    6  2010    66       C
# 9      NaN  194.0   8.6    69.0    5.0   10  2010    69       S
# 10     7.0    NaN   6.9     NaN    5.0   11  2010    74       C
# 23    32.0   92.0  12.0    61.0    NaN   24  2010    61       C
# 24     NaN   66.0  16.6    57.0    5.0   25  2010    57      PS
# 25     NaN  266.0  14.9    58.0    5.0   26  2010    58       C
# 26     NaN    NaN   8.0    57.0    5.0   27  2010    57      PS
# 31     NaN  286.0   8.6    78.0    6.0    1  2010    78       S
# 32     NaN  287.0   9.7    74.0    6.0    2  2010    74       C
# 33     NaN  242.0  16.1    67.0    6.0    3  2010    67      PS
# 34     NaN  186.0   9.2    84.0    6.0    4  2010    84       C
# 35     NaN  220.0   8.6    85.0    6.0    5  2010    85      PS
# 36     NaN  264.0  14.3    79.0    6.0    6  2010    79       C
# ...

# %%
## numerical values: missing values are replaced with either mean or median value of that columns, but it should be done with conscience.

# %%
data_cleaned3.isnull()
# Out:
#      Ozone  Solar   Wind  Temp C  Month    Day   Year   Temp  Weather
# 0    False  False  False   False  False  False  False  False    False
# 1    False  False  False   False  False  False  False  False    False
# 2    False  False  False   False  False  False  False  False    False
# 3    False  False  False   False  False  False  False  False    False
# 4     True   True  False   False  False  False  False  False    False
# ..     ...    ...    ...     ...    ...    ...    ...    ...      ...
# 153  False  False  False   False  False  False  False  False    False
# 154  False  False  False   False  False  False  False  False    False
# 155   True  False  False   False  False  False  False  False    False
# 156  False  False  False   False  False  False  False  False    False
# 157  False  False  False   False  False  False  False  False    False
#
# [158 rows x 9 columns]

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Temp C      1
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
data_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar    151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int64(3)
# memory usage: 10.3 KB

# %%
### mean impuutation
median= data_cleaned3['Solar'].median()
print(median)
# Out:
# 197.0

# %% [markdown]
# # TO FILL MISSSING VALUES, USE--- .fillna

# %%
data_cleaned3['Solar'] =data_cleaned3['Solar'].fillna(median)

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN  197.0  14.3    56.0    5.0    5  2010    56       S
# ..     ...    ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# ###HOME WORK : RAPLACE TEH NAN VALUES OF OZONE WITH ITS MEAN VALUE

# %%
### missing value imputation for categorical value
##df.mode
#df.median///
## get the object columns
### here generally categorical misssing values are replaced with mode of the column , eg: weather is having C, PS, S  variables

# %%
obj_columns=data_cleaned3[['Weather']]
obj_columns.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
data_cleaned3['Weather'].value_counts()
# Out:
# S     59
# C     49
# PS    47
# Name: Weather, dtype: int64

# %%
mode= obj_columns.mode().iloc[0] ## iloc is used to index the location of elements, [0]means oth row
mode
# Out:
# Weather    S
# Name: 0, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
obj_columns=obj_columns.fillna(mode)
obj_columns
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 1 columns]

# %% [markdown]
# # ADDING THE OBJECT COLUMNS

# %%
data_cleaned3['Weather'] = obj_columns['Weather']

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN  197.0  14.3    56.0    5.0    5  2010    56       S
# ..     ...    ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0  190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0  191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0  131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#data_cleaned3['Weather'] =obj_columns.fillna

#data_cleaned3            ##wrong

# %%
import matplotlib.pyplot as plt
plt.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.bar()
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'

# %% [markdown]
# # OTLIER DETECTION

# %%
HISTOGRAM OF OZONE
# Out:
#   Cell In[92], line 1
#     HISTOGRAM OF OZONE
#               ^
# SyntaxError: invalid syntax

# %%
data_cleaned3['Ozone'].hist()
# Out:
# <Axes: >

# %%
##it is likely to hv right skewed distrivbutiom

# %% [markdown]
# # BOXPLOT

# %%
plt.grid()
box =plt.boxplot(data['Ozone'], vert=False)  ## wrong plot

# %% [markdown]
# EXtracting OUTLIERS
