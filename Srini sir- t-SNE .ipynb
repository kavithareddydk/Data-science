# %%
from pandas import read_csv
import pandas as pd
import seaborn as sns
from sklearn.manifold import TSNE

# %%
# load data
filename = 'TSNE_data.csv'
dataframe = pd.read_csv(filename)
dataframe
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# Split-out validation dataset
array = dataframe.values
# separate array into input and output components
X = array[:,1:]
Y = array[:,0]

# %%
#TSNE visualization
#from bioinfokit.visuz import cluster

data_tsne = TSNE(n_components=2).fit_transform(X)
data_tsne
# cluster.tsneplot(score=data_tsne)
# Out:
# array([[ 38.988697 , -15.903841 ],
#        [ 39.538074 , -13.279122 ],
#        [ 35.03     , -12.582116 ],
#        ...,
#        [ 20.954346 ,  -3.0547073],
#        [ 37.45535  , -13.011096 ],
#        [-37.83512  , -25.39083  ]], dtype=float32)

# %%
tsne_df =pd.DataFrame(data_tsne, columns=["x1", "x2"])
tsne_df
# Out:
#             x1         x2
# 0    38.988697 -15.903841
# 1    39.538074 -13.279122
# 2    35.029999 -12.582116
# 3   -17.137877   1.727195
# 4    34.269085 -10.344901
# ..         ...        ...
# 564  41.133911 -12.883925
# 565  36.038349 -12.144411
# 566  20.954346  -3.054707
# 567  37.455349 -13.011096
# 568 -37.835121 -25.390829
#
# [569 rows x 2 columns]

# %%
tsne_df['diagnosis']=dataframe.diagnosis
tsne_df
# Out:
#             x1         x2 diagnosis
# 0    38.988697 -15.903841         M
# 1    39.538074 -13.279122         M
# 2    35.029999 -12.582116         M
# 3   -17.137877   1.727195         M
# 4    34.269085 -10.344901         M
# ..         ...        ...       ...
# 564  41.133911 -12.883925         M
# 565  36.038349 -12.144411         M
# 566  20.954346  -3.054707         M
# 567  37.455349 -13.011096         M
# 568 -37.835121 -25.390829         B
#
# [569 rows x 3 columns]

# %%
sns.scatterplot(data=tsne_df, x='x1', y="x2", hue='diagnosis', legend='full', alpha=1.0)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
if we have less numof data- go for PCA, if large num of data -then T-sne

# %% [markdown]
# # FOR PLOTTING 3D PLOT

# %%
data_tsne = TSNE(n_components=3).fit_transform(X)
data_tsne
# Out:
# array([[ 1.7646364e+01, -7.5069633e+00,  3.0534551e+00],
#        [ 1.7801683e+01, -5.8473325e+00,  4.0350022e+00],
#        [ 1.5610802e+01, -5.0764823e+00,  2.3870039e+00],
#        ...,
#        [ 9.9383402e+00, -4.0039211e-03, -3.8331916e+00],
#        [ 1.6770136e+01, -5.3919320e+00,  3.3453851e+00],
#        [-2.1931866e+01, -8.2019679e-02,  1.2575932e+00]], dtype=float32)

# %%
tsne_df =pd.DataFrame(data_tsne, columns=["x1", "x2", "x3"])
tsne_df
# Out:
#             x1        x2        x3
# 0    17.646364 -7.506963  3.053455
# 1    17.801683 -5.847332  4.035002
# 2    15.610802 -5.076482  2.387004
# 3    -7.665751 -1.803454  3.324735
# 4    15.123656 -3.517051  2.267334
# ..         ...       ...       ...
# 564  18.670441 -5.715925  4.621951
# 565  16.055281 -4.773625  2.901158
# 566   9.938340 -0.004004 -3.833192
# 567  16.770136 -5.391932  3.345385
# 568 -21.931866 -0.082020  1.257593
#
# [569 rows x 3 columns]

# %%
tsne_df['diagnosis']=dataframe.diagnosis
tsne_df
# Out:
#             x1        x2        x3 diagnosis
# 0    17.646364 -7.506963  3.053455         M
# 1    17.801683 -5.847332  4.035002         M
# 2    15.610802 -5.076482  2.387004         M
# 3    -7.665751 -1.803454  3.324735         M
# 4    15.123656 -3.517051  2.267334         M
# ..         ...       ...       ...       ...
# 564  18.670441 -5.715925  4.621951         M
# 565  16.055281 -4.773625  2.901158         M
# 566   9.938340 -0.004004 -3.833192         M
# 567  16.770136 -5.391932  3.345385         M
# 568 -21.931866 -0.082020  1.257593         B
#
# [569 rows x 4 columns]

# %%
sns.scatterplot(data=tsne_df, x=['x1','x2'], y="x2", hue='diagnosis', legend='full', alpha=1.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sns.scatterplot(data=tsne_df, x=['x1','x2'], y="x2", hue='diagnosis', legend='full', alpha=1.0)
#
# File ~\.conda\Lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     745     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
# get a list of categories
color_class = dataframe['diagnosis'].to_numpy()
cluster.tsneplot(score=data_tsne, colorlist=color_class, legendpos='upper right',legendanchor=(1.15, 1))

#Plot will be stored in the default directory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # get a list of categories
#       2 color_class = dataframe['diagnosis'].to_numpy()
# ----> 3 cluster.tsneplot(score=data_tsne, colorlist=color_class, legendpos='upper right',legendanchor=(1.15, 1))
#
# NameError: name 'cluster' is not defined

# %%
data_tsne
# Out:
# array([[-29.1934    ,  -0.67886114],
#        [-30.736988  ,   1.4434505 ],
#        [-27.561562  ,   5.410585  ],
#        ...,
#        [-12.8559065 ,  17.54113   ],
#        [-29.193478  ,   3.2486582 ],
#        [-12.616986  , -33.161873  ]], dtype=float32)
